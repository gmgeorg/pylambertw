# %% [markdown]
# # Demo: Gaussianize univariate and multivariate data using Lambert W x F distributions & transforms
#
# This tutorial shows how to use `torchlambertw` to use the sklearn API for fitting a `Gaussianizer()` transformer that can gaussianize univariate and multivariate data.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import os
import sys
import pathlib

from os.path import dirname
import logging
import datetime

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
parent_path = dirname(pathlib.Path(pathlib.Path(os.getcwd())))

if parent_path not in sys.path:
    sys.path.insert(0, parent_path)

# %%
import pylambertw

# %%
from pylambertw.utils import plot, moments
# Out:
# /home/georg/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /home/georg/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Load data
#
# This is an exchange rate dataset with exchange rates of multiple countries wrt to the US dollar.
#
# Data can be obtained from here
# https://pkgstore.datahub.io/core/exchange-rates/daily_csv/data/03e15e28c7eea87026fee299a8859e97/daily_csv.csv
#
# We are using this here to illustrate both univariate and multivariate Gaussianization using methods of moments (IGMM) and maximum likelihood estimation (MLE).

# %%
df = pd.read_csv("https://pkgstore.datahub.io/core/exchange-rates/daily_csv/data/03e15e28c7eea87026fee299a8859e97/daily_csv.csv")

# %%
df = df.rename(columns={v: v.lower() for v in df.columns})
df = df.set_index(["date", "country"], verify_integrity=True)
df_wide = pd.pivot_table(df, index="date", columns="country")
df_wide.columns = df_wide.columns.droplevel(0)
df_wide = df_wide.rename(columns={v: v.lower().replace(" ", "_") for v in df_wide.columns})

# %%
df_wide = df_wide.dropna()
df_wide
# Out:
# country     australia  brazil  canada   china  denmark    euro  hong_kong  \
# date
# 1999-01-04     1.6176  1.2074  1.5268  8.2793   6.3070  0.8466     7.7465
# 1999-01-05     1.6085  1.2075  1.5213  8.2795   6.3260  0.8503     7.7475
# 1999-01-06     1.5911  1.2110  1.5110  8.2795   6.3640  0.8594     7.7482
# 1999-01-07     1.5773  1.2100  1.5117  8.2798   6.3830  0.8568     7.7478
# 1999-01-08     1.5808  1.2095  1.5145  8.2796   6.4435  0.8655     7.7490
# ...               ...     ...     ...     ...      ...     ...        ...
# 2017-11-27     1.3149  3.2247  1.2745  6.5967   6.2472  0.8396     7.8011
# 2017-11-28     1.3129  3.2055  1.2804  6.6044   6.2654  0.8419     7.8020
# 2017-11-29     1.3207  3.2285  1.2850  6.6091   6.2760  0.8433     7.8083
# 2017-11-30     1.3207  3.2843  1.2884  6.6090   6.2543  0.8405     7.8093
# 2017-12-01     1.3116  3.2577  1.2705  6.6137   6.2476  0.8396     7.8118
#
# country     india   japan  malaysia  ...  norway  singapore  south_africa  \
# date                                 ...
# 1999-01-04  42.60  112.15    3.8000  ...  7.4960     1.6583        5.8675
# 1999-01-05  42.56  111.15    3.8000  ...  7.4340     1.6710        5.7625
# 1999-01-06  42.55  112.78    3.8000  ...  7.4355     1.6775        5.6775
# 1999-01-07  42.55  111.69    3.8000  ...  7.4050     1.6713        5.8400
# 1999-01-08  42.55  111.52    3.8000  ...  7.3970     1.6765        5.8350
# ...           ...     ...       ...  ...     ...        ...           ...
# 2017-11-27  64.47  111.00    4.1130  ...  8.1470     1.3461       13.7375
# 2017-11-28  64.40  111.13    4.1010  ...  8.2190     1.3447       13.5950
# 2017-11-29  64.29  111.75    4.0800  ...  8.2328     1.3466       13.6375
# 2017-11-30  64.46  112.30    4.0875  ...  8.2929     1.3482       13.6425
# 2017-12-01  64.50  111.88    4.0875  ...  8.2777     1.3450       13.7225
#
# country     south_korea  sweden  switzerland  taiwan  thailand  \
# date
# 1999-01-04      1187.50  8.0200       1.3666   32.13     36.20
# 1999-01-05      1166.00  7.9720       1.3694   32.25     36.18
# 1999-01-06      1160.00  7.9360       1.3852   32.25     36.50
# 1999-01-07      1151.00  7.9150       1.3863   32.13     36.30
# 1999-01-08      1174.00  7.9285       1.3970   32.22     36.45
# ...                 ...     ...          ...     ...       ...
# 2017-11-27      1088.36  8.2971       0.9804   30.02     32.61
# 2017-11-28      1079.87  8.3377       0.9831   29.98     32.55
# 2017-11-29      1079.33  8.3510       0.9837   30.02     32.57
# 2017-11-30      1084.79  8.3599       0.9838   29.98     32.58
# 2017-12-01      1082.36  8.3623       0.9762   30.02     32.59
#
# country     united_kingdom  venezuela
# date
# 1999-01-04          0.6031     0.5655
# 1999-01-05          0.6036     0.5660
# 1999-01-06          0.6043     0.5658
# 1999-01-07          0.6062     0.5665
# 1999-01-08          0.6096     0.5671
# ...                    ...        ...
# 2017-11-27          0.7500     9.9750
# 2017-11-28          0.7558     9.9750
# 2017-11-29          0.7443     9.9750
# 2017-11-30          0.7404     9.9750
# 2017-12-01          0.7405     9.9750
#
# [4744 rows x 22 columns]

# %%
df_wide[["euro", "brazil"]].plot()
plt.grid()

# %% [markdown]
# Computing daily log-returns for each currency rate.

# %%
df_ret = np.log(df_wide).diff().dropna() * 100
df_ret[["euro", "brazil"]].plot()
plt.grid()

# %% [markdown]
# ## Univariate data
#
# We are only going to look at the "euro" exchange rate returns for univariate analysis; below we will then revisit a multivariate analysis.

# %%
plot.test_norm(df_ret["euro"])

# %%
from pylambertw import igmm

mod = igmm.IGMM()
mod.fit(df_ret["euro"])
mod.tau
# Out:
# /home/georg/Projects/pylambertw/pylambertw/igmm.py:208: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   data = data[:, np.newaxis]
# Lambert W x F (type: 'h')
# 	loc=[-0.00012045]; scale=[0.53003692]
# 	delta: [0.10140152]; alpha: [1.]

# %%
from pylambertw.preprocessing import gaussianizing
clf = gaussianizing.Gaussianizer(lambertw_type="h", method="igmm")
clf.fit(df_ret["euro"])
# Out:
# /home/georg/Projects/pylambertw/pylambertw/preprocessing/gaussianizing.py:45: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   data = data[:, np.newaxis]
# 100%|██████████| 1/1 [00:00<00:00,  5.58it/s]

# %%
clf.estimators
# Out:
# [IGMM(lambertw_type=<LambertWType.H: 'h'>)]

# %%
x = clf.transform(df_ret["euro"])
# Out:
# /home/georg/Projects/pylambertw/pylambertw/preprocessing/gaussianizing.py:74: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   data = data[:, np.newaxis]

# %%
plot.test_norm(x)

# %% [markdown]
# ## Multivariate data
#
# For the multivariate analysis and Gaussianization we are looking at all 22 rates overall, and then check in particular the (Euro, Brazil, US) dependencies.

# %%
sns.clustermap(df_ret.corr())

# %%
df_ret.apply(moments.kurtosis, axis=0).sort_values().plot.barh()
# Out:
# <AxesSubplot:ylabel='country'>

# %%
df_ret["venezuela"].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Dropping `"venezuela"` as it has extended periods of exact 0. change and thus not a continous distribution.

# %%
df_ret = df_ret.drop("venezuela", axis=1)

# %%
sns.clustermap(df_ret.corr(), cmap="Spectral", center=0.5)

# %%
df_ret.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_ret.apply(moments.kurtosis, axis=0).sort_values().plot.barh()
plt.grid()

# %%
clf = gaussianizing.Gaussianizer(lambertw_type="h", method="igmm")

# %%
clf.fit(df_ret)
# Out:
# 100%|██████████| 21/21 [00:04<00:00,  4.91it/s]

# %%
clf.params
# Out:
#                      loc     scale     delta
# country
# australia      -0.013557  0.595111  0.164597
# brazil          0.010241  0.697263  0.229400
# canada         -0.004303  0.435170  0.149713
# china          -0.002830  0.030972  0.638387
# denmark         0.000280  0.521806  0.117920
# euro           -0.000120  0.530037  0.101402
# hong_kong       0.000592  0.011375  0.483631
# india           0.003832  0.239700  0.317584
# japan           0.003209  0.523155  0.134030
# malaysia        0.001601  0.146829  0.487810
# mexico          0.004388  0.464657  0.187898
# new_zealand    -0.013113  0.668182  0.132899
# norway         -0.001198  0.619286  0.122503
# singapore      -0.004688  0.259165  0.146260
# south_africa    0.009946  0.830601  0.143675
# south_korea    -0.010085  0.381952  0.272915
# sweden          0.000763  0.610932  0.123667
# switzerland    -0.003383  0.543397  0.129228
# taiwan         -0.001157  0.181906  0.278198
# thailand       -0.003057  0.244482  0.251572
# united_kingdom  0.000089  0.467163  0.132122

# %%
sns.pairplot(clf.params)

# %%
sns.clustermap(clf.params)

# %%
df_ret_gauss = clf.transform(df_ret)
df_ret_gauss.apply(moments.kurtosis, axis=0).sort_values().plot.barh()
plt.grid()

# %%
sns.clustermap(df_ret_gauss.corr())

# %%
selected = ["south_africa", "euro"]
df_ret[selected].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.jointplot(data=df_ret[selected], x="euro", y="south_africa")

# %%
plot.test_norm(df_ret["euro"])
plot.test_norm(df_ret["south_africa"])

# %%
sns.jointplot(data=df_ret_gauss[selected], x="euro", y="south_africa")

# %%
plot.test_norm(df_ret_gauss["euro"])
plot.test_norm(df_ret_gauss["south_africa"])

# %%
df_ret[selected].cumsum().plot()
plt.grid()

# %%
df_ret_gauss[selected].cumsum().plot()
plt.grid()

# %%
df_ret[selected].cov()
# Out:
# country       south_africa      euro
# country
# south_africa      1.147125  0.274009
# euro              0.274009  0.393305

# %%
df_ret_gauss[selected].cov()
# Out:
# country       south_africa      euro
# country
# south_africa      0.690043  0.181076
# euro              0.181076  0.280998

# %%
rng = np.random.RandomState(seed=42)
X = rng.standard_cauchy(size=(1000, 2))
clf = gaussianizing.Gaussianizer(lambertw_type="h", method="igmm")
clf.fit(X)

X_gauss = clf.transform(X)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  7.20it/s]

# %%
print(pylambertw.utils.moments.skewness(X), pylambertw.utils.moments.kurtosis(X))

print(pylambertw.utils.moments.skewness(X_gauss),pylambertw.utils.moments.kurtosis(X_gauss))
# Out:
# [-29.96366924  30.54780708] [929.58443573 953.16027739]
# [0.00728701 0.13284473] [2.99999955 2.99999953]
